# %%
from simulation_manager import SimpleBuilding, BuildingEnergySimulator
import pandas as pd
import matplotlib.pyplot as plt

# %%
simple_building = SimpleBuilding(thermal_capacitance = 3e+6, thermal_conductance = 300.0)
bes = BuildingEnergySimulator(timestep = 10.0)
bes.add_building(simple_building)

# %%
bes.load_outdoor_temperature_data("smhi_borås.csv")

# %%
plt.plot(bes.outdoor_temperature_data["timestamp"], bes.outdoor_temperature_data["Lufttemperatur"])
plt.xlabel("Time")
plt.ylabel("Outdoor Temperature (°C)")
plt.show()
