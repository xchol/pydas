# %%
import numpy as np

# %%
import pydas.simulation_manager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pydas.simulation_manager
#
# ModuleNotFoundError: No module named 'pydas'
